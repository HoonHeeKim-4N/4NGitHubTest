# %%
import pandas as pd
import numpy as np
print('ctest')
# Out:
# ctest

# %%
train_df = pd.read_csv('s3://nmlt201021/EEGTest.csv')
train_df
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3072: DtypeWarning: Columns (1) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#        Unnamed: 0             time  event           ch1           ch2  \
# 0               0  16-17-29.928303    1.0      0.000000      0.000000
# 1               0              0.0    1.0  45078.484127  46072.846183
# 2               1              0.0    1.0  90105.648649  92085.834394
# 3               2              0.0    1.0  90138.617472  92104.855729
# 4               3              0.0    1.0  90129.341499  92133.980052
# ...           ...              ...    ...           ...           ...
# 42019        1017               99    1.0  83826.440135  85575.955877
# 42020        1018               99    1.0  83780.462596  85530.648891
# 42021        1019               99    1.0  83817.119457  85564.578839
# ...
